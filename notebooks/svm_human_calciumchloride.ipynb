# %%
from subpred.protein_go_datasets import get_transmembrane_transporter_dataset, get_stats

# %% [markdown]
# ## Parameters

# %%
ORGANISMS = [9606]  # athaliana 3702 yeast 559292 human 9606 ecoli 83333
GO_TERMS_CLASSES = [
    "calcium channel activity",
    "chloride channel activity",
]
IDENTITY_THRESHOLD = 70
TEST_NAME = "svc_human_calciumchloride"
# TODO pathlib
FEATURES_FOLDER = "../data/tmp_data/"  # to share between environments
RESULTS_FOLDER = "../data/results/"
RECALCULATE_RESULTS = False  # TODO If false, use cached results, e.g. to create more plots

# %% [markdown]
# ## Full dataset

# %%
# Get full dataset for stats. Dataset for analysis is created in cell below.
dataset_unfiltered = get_transmembrane_transporter_dataset( 
    organism_ids=ORGANISMS,
    swissprot_only=False,
    datasets_path="../data/datasets/",
    exclude_iea_go_terms=False,
    max_sequence_evidence_code=2,
    remove_proteins_without_gene_names=False,
)
get_stats(*dataset_unfiltered)
# Out:
# cd-hit: clustered 3874 sequences into 1029 clusters at threshold 50
# cd-hit: clustered 3874 sequences into 1347 clusters at threshold 70
# cd-hit: clustered 3874 sequences into 1774 clusters at threshold 90
# cd-hit: clustered 3874 sequences into 3408 clusters at threshold 100
#                                                                                       n_transporters  \
# swissprot_reviewed has_gene_name go_evidence   protein_existence_evidence clustering
# False              False         computational protein_level              50                       1
#                                                                           70                       1
#                                                                           90                       5
#                                                                           100                      9
#                                                                           None                    10
#                                                transcript_level           50                      54
#                                                                           70                      77
#                                                                           90                     152
#                                                                           100                    665
#                                                                           None                   771
#                                  experiment    transcript_level           50                       1
#                                                                           70                       1
#                                                                           90                       1
#                                                                           100                      2
#                                                                           None                     2
#                    True          computational protein_level              50                     142
#                                                                           70                     211
#                                                                           90                     419
#                                                                           100                   1031
#                                                                           None                  1175
#                                                transcript_level           50                      31
#                                                                           70                      46
#                                                                           90                     100
#                                                                           100                    501
#                                                                           None                   687
#                                  experiment    transcript_level           50                       1
#                                                                           70                       1
#                                                                           90                       2
#                                                                           100                      4
#                                                                           None                     5
# True               True          computational protein_level              50                     552
#                                                                           70                     741
#                                                                           90                     819
#                                                                           100                    919
#                                                                           None                   945
#                                                transcript_level           50                       6
#                                                                           70                      10
#                                                                           90                      12
#                                                                           100                     13
#                                                                           None                    13
#                                  experiment    protein_level              50                     730
#                                                                           70                     921
#                                                                           90                     996
#                                                                           100                   1092
#                                                                           None                  1121
#                                                transcript_level           50                       8
#                                                                           70                      13
#                                                                           90                      14
#                                                                           100                     15
#                                                                           None                    15
#
#                                                                                       n_terms
# swissprot_reviewed has_gene_name go_evidence   protein_existence_evidence clustering
# False              False         computational protein_level              50                7
#                                                                           70                7
#                                                                           90               24
#                                                                           100              24
#                                                                           None             28
#                                                transcript_level           50              123
#                                                                           70              134
#                                                                           90              153
#                                                                           100             257
#                                                                           None            261
#                                  experiment    transcript_level           50               13
#                                                                           70               13
#                                                                           90               13
#                                                                           100              13
#                                                                           None             13
#                    True          computational protein_level              50              177
#                                                                           70              199
#                                                                           90              209
#                                                                           100             240
#                                                                           None            250
#                                                transcript_level           50               91
#                                                                           70              107
#                                                                           90              129
#                                                                           100             189
#                                                                           None            237
#                                  experiment    transcript_level           50               19
#                                                                           70               19
#                                                                           90               22
#                                                                           100              29
#                                                                           None             40
# True               True          computational protein_level              50              398
#                                                                           70              448
#                                                                           90              456
#                                                                           100             469
#                                                                           None            471
#                                                transcript_level           50               49
#                                                                           70               59
#                                                                           90               59
#                                                                           100              61
#                                                                           None             61
#                                  experiment    protein_level              50              503
#                                                                           70              543
#                                                                           90              550
#                                                                           100             567
#                                                                           None            570
#                                                transcript_level           50               60
#                                                                           70               71
#                                                                           90               71
#                                                                           100              71
#                                                                           None             71

# %% [markdown]
# ## Filtered Subset

# %%
dataset_organism = get_transmembrane_transporter_dataset(  # organism
    organism_ids=ORGANISMS,
    swissprot_only=True,
    datasets_path="../data/datasets/",
    exclude_iea_go_terms=True,
    max_sequence_evidence_code=1,
    remove_proteins_without_gene_names=True,
)
get_stats(*dataset_organism)
# Out:
# cd-hit: clustered 1121 sequences into 846 clusters at threshold 50
# cd-hit: clustered 1121 sequences into 1039 clusters at threshold 70
# cd-hit: clustered 1121 sequences into 1110 clusters at threshold 90
# cd-hit: clustered 1121 sequences into 1118 clusters at threshold 100
#                                                                                     n_transporters  \
# swissprot_reviewed has_gene_name go_evidence protein_existence_evidence clustering
# True               True          experiment  protein_level              50                     846
#                                                                         70                    1039
#                                                                         90                    1110
#                                                                         100                   1118
#                                                                         None                  1121
#
#                                                                                     n_terms
# swissprot_reviewed has_gene_name go_evidence protein_existence_evidence clustering
# True               True          experiment  protein_level              50              534
#                                                                         70              563
#                                                                         90              570
#                                                                         100             570
#                                                                         None            570

# %%
from subpred.protein_go_datasets import count_children
display(count_children(dataset_organism=dataset_organism, go_term="monoatomic anion channel activity"))
count_children(dataset_organism=dataset_organism, go_term="monoatomic cation channel activity")
# Out:
#                                                  Uniprot
# go_term_ancestor
# monoatomic anion channel activity                     89
# chloride channel activity                             72
# ligand-gated monoatomic anion channel activity        42
# voltage-gated monoatomic anion channel activity       17
# volume-sensitive anion channel activity                8
# iodide channel activity                                1
# fluoride channel activity                              1
#                                                     Uniprot
# go_term_ancestor
# monoatomic cation channel activity                      289
# ligand-gated monoatomic cation channel activity         129
# voltage-gated monoatomic cation channel activity        115
# calcium channel activity                                105
# potassium channel activity                              100
# sodium channel activity                                  46
# proton channel activity                                  13
# mechanosensitive monoatomic cation channel acti...        8
# osmolarity-sensing monoatomic cation channel ac...        4
# temperature-gated cation channel activity                 2

# %% [markdown]
# ## Subset

# %%
from subpred.dataset_filters import get_classification_subset
dataset_organism = get_classification_subset(dataset_full=dataset_organism, go_terms=GO_TERMS_CLASSES, remove_duplicates=True)

print("before clustering:")
dataset_organism[1].go_term_ancestor.value_counts()
# Out:
# before clustering:
# go_term_ancestor
# calcium channel activity     104
# chloride channel activity     72
# Name: count, dtype: int64

# %%
from subpred.dataset_filters import filter_no_3Di_available

dataset_organism = filter_no_3Di_available(dataset_organism)
dataset_organism[1].go_term_ancestor.value_counts()
# Out:
# go_term_ancestor
# calcium channel activity     103
# chloride channel activity     71
# Name: count, dtype: int64

# %% [markdown]
# Clustering at 70%

# %%
from subpred.dataset_filters import cluster_sequences
dataset_organism = cluster_sequences(dataset_full=dataset_organism, identity_threshold=IDENTITY_THRESHOLD)
dataset_organism[1].go_term_ancestor.value_counts()
# Out:
# cd-hit: clustered 174 sequences into 159 clusters at threshold 70
# go_term_ancestor
# calcium channel activity     100
# chloride channel activity     59
# Name: count, dtype: int64

# %% [markdown]
# ## Feature generation

# %%
from subpred.features import get_features
features_list, series_labels = get_features(dataset_full=dataset_organism)
# Out:
# 2025-06-01 13:20:21.373235: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-01 13:20:21.379705: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748776821.386105    5437 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748776821.388230    5437 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-01 13:20:21.395226: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# For each Feature: Outlier detection, numpy conversion

# %%
from subpred.features import get_ml_datasets
ml_datasets = list(get_ml_datasets(features_list=features_list, series_labels=series_labels))
ml_datasets
# Out:
# [Name: DUMMY, Features: 1024, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: AAC, Features: 20, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: PAAC, Features: 400, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: AA_KMER3, Features: 8000, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: 3Di_COMP, Features: 20, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: 3Di_KMER2, Features: 400, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: 3Di_KMER3, Features: 8000, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: COMB_KMER1, Features: 40, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: COMB_KMER2, Features: 800, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: COMB_KMER3, Features: 16000, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: PROTT5_AA, Features: 1024, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: PROSTT5_AA, Features: 1024, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: PROSTT5_3DI, Features: 1024, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: PSSM_50_1, Features: 400, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: PSSM_50_3, Features: 400, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: PSSM_90_1, Features: 400, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: PSSM_90_3, Features: 400, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: PSSM_META, Features: 1600, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: META, Features: 2020, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity']),
#  Name: META_STD, Features: 2020, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity'])]

# %%
# saving as pickle, to load in different notebook with different env, 
# as tensorflow on GPU has problems with current CUDA version (too new)
import pickle
with open(f"{FEATURES_FOLDER}{TEST_NAME}_ml_data.pickle", 'wb') as handle:
    pickle.dump(ml_datasets, handle)

# %% [markdown]
# ## Outliers

# %%
from subpred.evaluation import outlier_check

outlier_check(dataset_full=dataset_organism,ml_datasets=ml_datasets, threshold=0.8)
# Out:
# Empty DataFrame
# Columns: [outlier_count, protein_names, go_term_ancestor]
# Index: []

# %% [markdown]
# ## Model evaluation SVM

# %%
ml_datasets = [ml_dataset for ml_dataset in ml_datasets if "T5" in ml_dataset.name] + [
    ml_dataset for ml_dataset in ml_datasets if "T5" not in ml_dataset.name
]

# %%
ml_datasets[0]
# Out:
# Name: PROTT5_AA, Features: 1024, Samples: 159, Classes: [0 1], Labels: ['calcium channel activity' 'chloride channel activity'])

# %%
from subpred.evaluation import get_svm_results, plot_results_long, summarize_results_long
from sklearn.metrics import f1_score, make_scorer

scoring_outer = {
    "Balanced Accuracy": "balanced_accuracy",
    "F1 Macro": "f1_macro",
    "F1 Calcium Channel": make_scorer(
        f1_score, pos_label=0
    ),  # labels are encoded in lex. order
    "F1 Chloride Channel": make_scorer(f1_score, pos_label=1),
}

df_results_long = get_svm_results(
    ml_datasets=ml_datasets,
    recalculate=RECALCULATE_RESULTS,
    output_folder=RESULTS_FOLDER,
    test_name=TEST_NAME,
    inner_cv=5,
    outer_cv=5,
    repeats=10,
    n_jobs_inner=1,
    n_jobs_outer=-1,
    scoring_inner="balanced_accuracy",
    scoring_outer=scoring_outer,
)
# Out:
# === PROTT5_AA ===
# Balanced Accuracy: 0.90+-0.05
# F1 Macro: 0.90+-0.05
# F1 Calcium Channel: 0.93+-0.04
# F1 Chloride Channel: 0.87+-0.07
# === PROSTT5_AA ===
# Balanced Accuracy: 0.90+-0.05
# F1 Macro: 0.90+-0.05
# F1 Calcium Channel: 0.93+-0.04
# F1 Chloride Channel: 0.88+-0.06
# === PROSTT5_3DI ===
# Balanced Accuracy: 0.89+-0.06
# F1 Macro: 0.89+-0.06
# F1 Calcium Channel: 0.92+-0.05
# F1 Chloride Channel: 0.86+-0.07
# === DUMMY ===
# Balanced Accuracy: 0.45+-0.06
# F1 Macro: 0.42+-0.07
# F1 Calcium Channel: 0.64+-0.10
# F1 Chloride Channel: 0.20+-0.12
# === AAC ===
# Balanced Accuracy: 0.67+-0.09
# F1 Macro: 0.67+-0.09
# F1 Calcium Channel: 0.75+-0.08
# F1 Chloride Channel: 0.59+-0.11
# === PAAC ===
# Balanced Accuracy: 0.76+-0.09
# F1 Macro: 0.77+-0.09
# F1 Calcium Channel: 0.84+-0.06
# F1 Chloride Channel: 0.69+-0.12
# === AA_KMER3 ===
# Balanced Accuracy: 0.71+-0.08
# F1 Macro: 0.69+-0.08
# F1 Calcium Channel: 0.74+-0.09
# F1 Chloride Channel: 0.64+-0.09
# === 3Di_COMP ===
# Balanced Accuracy: 0.84+-0.06
# F1 Macro: 0.84+-0.06
# F1 Calcium Channel: 0.88+-0.05
# F1 Chloride Channel: 0.80+-0.07
# === 3Di_KMER2 ===
# Balanced Accuracy: 0.85+-0.06
# F1 Macro: 0.85+-0.06
# F1 Calcium Channel: 0.89+-0.04
# F1 Chloride Channel: 0.81+-0.08
# === 3Di_KMER3 ===
# Balanced Accuracy: 0.83+-0.07
# F1 Macro: 0.83+-0.07
# F1 Calcium Channel: 0.87+-0.06
# F1 Chloride Channel: 0.79+-0.09
# === COMB_KMER1 ===
# Balanced Accuracy: 0.81+-0.07
# F1 Macro: 0.82+-0.07
# F1 Calcium Channel: 0.87+-0.05
# F1 Chloride Channel: 0.76+-0.10
# === COMB_KMER2 ===
# Balanced Accuracy: 0.86+-0.06
# F1 Macro: 0.86+-0.06
# F1 Calcium Channel: 0.90+-0.05
# F1 Chloride Channel: 0.82+-0.08
# === COMB_KMER3 ===
# Balanced Accuracy: 0.79+-0.08
# F1 Macro: 0.78+-0.09
# F1 Calcium Channel: 0.83+-0.07
# F1 Chloride Channel: 0.74+-0.10
# === PSSM_50_1 ===
# Balanced Accuracy: 0.75+-0.09
# F1 Macro: 0.75+-0.09
# F1 Calcium Channel: 0.82+-0.06
# F1 Chloride Channel: 0.68+-0.11
# === PSSM_50_3 ===
# Balanced Accuracy: 0.80+-0.07
# F1 Macro: 0.79+-0.07
# F1 Calcium Channel: 0.85+-0.06
# F1 Chloride Channel: 0.74+-0.09
# === PSSM_90_1 ===
# Balanced Accuracy: 0.72+-0.09
# F1 Macro: 0.72+-0.09
# F1 Calcium Channel: 0.79+-0.08
# F1 Chloride Channel: 0.65+-0.11
# === PSSM_90_3 ===
# Balanced Accuracy: 0.72+-0.09
# F1 Macro: 0.72+-0.09
# F1 Calcium Channel: 0.79+-0.08
# F1 Chloride Channel: 0.65+-0.11
# === PSSM_META ===
# Balanced Accuracy: 0.76+-0.08
# F1 Macro: 0.75+-0.08
# F1 Calcium Channel: 0.82+-0.07
# F1 Chloride Channel: 0.69+-0.10
# === META ===
# Balanced Accuracy: 0.79+-0.08
# F1 Macro: 0.79+-0.08
# F1 Calcium Channel: 0.85+-0.05
# F1 Chloride Channel: 0.73+-0.10
# === META_STD ===
# Balanced Accuracy: 0.81+-0.07
# F1 Macro: 0.81+-0.07
# F1 Calcium Channel: 0.85+-0.06
# F1 Chloride Channel: 0.76+-0.08

# %%
summarize_results_long(df_results_long=df_results_long)
# Out:
#                                    Mean    Median      Sdev
# Feature   Metric
# 3Di_COMP  Balanced Accuracy    0.843227  0.841667  0.058110
#           F1 Calcium Channel   0.881823  0.888889  0.047703
#           F1 Chloride Channel  0.802367  0.800000  0.071534
#           F1 Macro             0.842095  0.846110  0.058324
# 3Di_KMER2 Balanced Accuracy    0.848924  0.845833  0.063559
# ...                                 ...       ...       ...
# PSSM_90_3 F1 Macro             0.717931  0.713984  0.088612
# PSSM_META Balanced Accuracy    0.755303  0.779167  0.078939
#           F1 Calcium Channel   0.815139  0.831301  0.066258
#           F1 Chloride Channel  0.690913  0.720000  0.098462
#           F1 Macro             0.753026  0.770256  0.079247
#
# [80 rows x 3 columns]

# %%
plot_results_long(
    df_results_long=df_results_long,
    output_folder_path=RESULTS_FOLDER,
    test_name=TEST_NAME,
    metrics_include = ["F1 Amino Acid","F1 Sugar"]
)

# %%
plot_results_long(
    df_results_long=df_results_long,
    output_folder_path=RESULTS_FOLDER,
    test_name=TEST_NAME,
    metrics_include = ["F1 Macro", "Balanced Accuracy"]
)
