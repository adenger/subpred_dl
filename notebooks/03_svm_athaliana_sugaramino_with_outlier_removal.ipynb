# %%
from subpred.protein_go_datasets import get_transmembrane_transporter_dataset, get_stats, get_interpro_annotations

# %% [markdown]
# Same notebook, but with automatic outlier removal to see impact on training scores.

# %% [markdown]
# ## Parameters

# %%
import pandas as pd
pd.set_option('display.max_rows', 100)

# %%
ORGANISMS = [3702]  # athaliana 3702 yeast 559292 human 9606 ecoli 83333
GO_TERMS_CLASSES = [
    "sugar transmembrane transporter activity",
    "amino acid transmembrane transporter activity",
]
IDENTITY_THRESHOLD = 70
TEST_NAME = "svc_at_sugaramino_outlier_removal"
# TODO pathlib
FEATURES_FOLDER = "../data/tmp_data/"  # to share between environments
RESULTS_FOLDER = "../data/results/"
RECALCULATE_RESULTS = True  # If false, use cached results, e.g. to create more plots

# %% [markdown]
# ## Full dataset

# %%
# Get full dataset for stats. Dataset for analysis is created in cell below.
dataset_unfiltered = get_transmembrane_transporter_dataset(
    organism_ids=ORGANISMS,
    swissprot_only=False,
    datasets_path="../data/datasets/",
    exclude_iea_go_terms=False,
    max_sequence_evidence_code=2,
    remove_proteins_without_gene_names=False,
)
get_stats(*dataset_unfiltered)
# Out:
# cd-hit: clustered 1773 sequences into 646 clusters at threshold 50
# cd-hit: clustered 1773 sequences into 923 clusters at threshold 70
# cd-hit: clustered 1773 sequences into 1203 clusters at threshold 90
# cd-hit: clustered 1773 sequences into 1554 clusters at threshold 100
#                                                                                       n_transporters  \
# swissprot_reviewed has_gene_name go_evidence   protein_existence_evidence clustering
# False              False         computational protein_level              100                      3
#                                                                           None                     3
#                                                transcript_level           50                       3
#                                                                           70                       4
#                                                                           90                       7
#                                                                           100                     37
#                                                                           None                    49
#                    True          computational protein_level              50                      87
#                                                                           70                     114
#                                                                           90                     153
#                                                                           100                    329
#                                                                           None                   433
#                                                transcript_level           50                       7
#                                                                           70                      13
#                                                                           90                      19
#                                                                           100                     84
#                                                                           None                   164
#                                  experiment    protein_level              50                      25
#                                                                           70                      33
#                                                                           90                      38
#                                                                           100                     41
#                                                                           None                    42
#                                                transcript_level           50                       3
#                                                                           70                       5
#                                                                           90                       5
#                                                                           100                      6
#                                                                           None                     6
# True               True          computational protein_level              50                     206
#                                                                           70                     287
#                                                                           90                     370
#                                                                           100                    408
#                                                                           None                   418
#                                                transcript_level           50                     208
#                                                                           70                     338
#                                                                           90                     462
#                                                                           100                    492
#                                                                           None                   504
#                                  experiment    protein_level              50                     218
#                                                                           70                     297
#                                                                           90                     383
#                                                                           100                    414
#                                                                           None                   420
#                                                transcript_level           50                     202
#                                                                           70                     314
#                                                                           90                     424
#                                                                           100                    452
#                                                                           None                   460
#
#                                                                                       n_terms
# swissprot_reviewed has_gene_name go_evidence   protein_existence_evidence clustering
# False              False         computational protein_level              100              11
#                                                                           None             11
#                                                transcript_level           50                4
#                                                                           70                7
#                                                                           90                6
#                                                                           100              66
#                                                                           None             77
#                    True          computational protein_level              50              110
#                                                                           70              114
#                                                                           90              119
#                                                                           100             129
#                                                                           None            137
#                                                transcript_level           50               36
#                                                                           70               36
#                                                                           90               35
#                                                                           100              83
#                                                                           None            102
#                                  experiment    protein_level              50               38
#                                                                           70               38
#                                                                           90               38
#                                                                           100              39
#                                                                           None             39
#                                                transcript_level           50                9
#                                                                           70                9
#                                                                           90                9
#                                                                           100               9
#                                                                           None              9
# True               True          computational protein_level              50              141
#                                                                           70              152
#                                                                           90              154
#                                                                           100             158
#                                                                           None            158
#                                                transcript_level           50              112
#                                                                           70              131
#                                                                           90              143
#                                                                           100             146
#                                                                           None            146
#                                  experiment    protein_level              50              238
#                                                                           70              267
#                                                                           90              284
#                                                                           100             288
#                                                                           None            288
#                                                transcript_level           50              171
#                                                                           70              200
#                                                                           90              216
#                                                                           100             225
#                                                                           None            225

# %% [markdown]
# ## Filtered Subset

# %%
dataset_organism = get_transmembrane_transporter_dataset(  # organism
    organism_ids=ORGANISMS,
    swissprot_only=True,
    datasets_path="../data/datasets/",
    exclude_iea_go_terms=True,
    max_sequence_evidence_code=1,
    remove_proteins_without_gene_names=True,
)
get_stats(*dataset_organism)
# Out:
# cd-hit: clustered 420 sequences into 276 clusters at threshold 50
# cd-hit: clustered 420 sequences into 344 clusters at threshold 70
# cd-hit: clustered 420 sequences into 403 clusters at threshold 90
# cd-hit: clustered 420 sequences into 419 clusters at threshold 100
#                                                                                     n_transporters  \
# swissprot_reviewed has_gene_name go_evidence protein_existence_evidence clustering
# True               True          experiment  protein_level              50                     276
#                                                                         70                     344
#                                                                         90                     403
#                                                                         100                    419
#                                                                         None                   420
#
#                                                                                     n_terms
# swissprot_reviewed has_gene_name go_evidence protein_existence_evidence clustering
# True               True          experiment  protein_level              50              264
#                                                                         70              281
#                                                                         90              288
#                                                                         100             288
#                                                                         None            288

# %% [markdown]
# ## Sugar/Amino subset

# %%
from subpred.dataset_filters import get_classification_subset

dataset_organism = get_classification_subset(
    dataset_full=dataset_organism, go_terms=GO_TERMS_CLASSES
)

print("before clustering:")
dataset_organism[1].go_term_ancestor.value_counts()
# Out:
# before clustering:
# go_term_ancestor
# amino acid transmembrane transporter activity    33
# sugar transmembrane transporter activity         32
# Name: count, dtype: int64

# %%
from subpred.dataset_filters import filter_no_3Di_available

dataset_organism = filter_no_3Di_available(dataset_organism)
dataset_organism[1].go_term_ancestor.value_counts()
# Out:
# go_term_ancestor
# amino acid transmembrane transporter activity    33
# sugar transmembrane transporter activity         32
# Name: count, dtype: int64

# %% [markdown]
# Clustering at 70%

# %%
from subpred.dataset_filters import cluster_sequences

dataset_organism = cluster_sequences(
    dataset_full=dataset_organism, identity_threshold=IDENTITY_THRESHOLD
)
dataset_organism[1].go_term_ancestor.value_counts()
# Out:
# cd-hit: clustered 65 sequences into 54 clusters at threshold 70
# go_term_ancestor
# sugar transmembrane transporter activity         28
# amino acid transmembrane transporter activity    26
# Name: count, dtype: int64

# %% [markdown]
# ### Interpro annotations

# %%
from subpred.protein_go_datasets import count_interpro_annotations, get_interpro_table

count_interpro_annotations(dataset_organism[1], GO_TERMS_CLASSES)
# Out:
# ######## sugar transmembrane transporter activity ########
# Family
# Sugar transporter SWEET                                      13
# Sugar/inositol transporter                                   12
# Major facilitator, sugar transporter-like                    12
# Sugar transport protein STP/Polyol transporter PLT, plant     8
# Sugar transport protein STP/MST-like, plant                   7
# Major Facilitator Superfamily Trehalose Transporter           2
# Sugar transporter ERD6/Tret1-like                             2
# Major Facilitator Superfamily Sugar Transporter               2
# Major facilitator superfamily                                 2
# Solute carrier family 17 member 9-like                        1
# Major Facilitator Superfamily Sodium/Anion Cotransporter      1
# Polyol transporter 1-6                                        1
# Triose Phosphate/Phosphate Translocator                       1
# Sucrose/H+ symporter, plant                                   1
# Name: count, dtype: int64
#
# Domain
# Major facilitator superfamily domain    13
# Sugar phosphate transporter domain       1
# Name: count, dtype: int64
#
# Repeat
# Sugar transporter SWEET repeat    13
# Name: count, dtype: int64
#
# Homologous_superfamily
# MFS transporter superfamily    15
# Name: count, dtype: int64
#
# Conserved_site
# Sugar transporter, conserved site    12
# Name: count, dtype: int64
#
# ######## amino acid transmembrane transporter activity ########
# Family
# Amino acid/polyamine transporter I      4
# Mitochondrial Carrier                   3
# Mitochondrial carrier protein           2
# Mitochondrial Metabolite Transporter    1
# Lysosomal cystine transporter           1
# Ionotropic glutamate receptor           1
# Ionotropic glutamate receptor, plant    1
# Citrate carrier CitT-related            1
# Solute carrier family 13                1
# WAT1-related protein                    1
# Tim23-like                              1
# Name: count, dtype: int64
#
# Domain
# Amino acid transporter, transmembrane domain                   13
# Cationic amino acid transporter, C-terminal                     4
# Solute-binding protein family 3/N-terminal domain of MltF       1
# Ionotropic glutamate receptor, C-terminal                       1
# Plant glutamate receptor, periplasmic ligand-binding domain     1
# Receptor, ligand binding region                                 1
# EamA domain                                                     1
# Name: count, dtype: int64
#
# Repeat
# Mitochondrial substrate/solute carrier    4
# PQ-loop repeat                            1
# Name: count, dtype: int64
#
# Homologous_superfamily
# Mitochondrial carrier domain superfamily    4
# Periplasmic binding protein-like I          1
# Name: count, dtype: int64

# %%
# Some proteins have multiple rows!
get_interpro_table(
    *dataset_organism,
    go_terms=["sugar transmembrane transporter activity"],
    interpro_types=["Family", "Homologous_superfamily"]
)
# Out:
#    Uniprot                          go_term_ancestor  \
# 0   O04036  sugar transmembrane transporter activity
# 1   O04036  sugar transmembrane transporter activity
# 2   O04036  sugar transmembrane transporter activity
# 3   O04036  sugar transmembrane transporter activity
# 4   O04249  sugar transmembrane transporter activity
# 5   O04249  sugar transmembrane transporter activity
# 6   O04249  sugar transmembrane transporter activity
# 7   O04249  sugar transmembrane transporter activity
# 8   P23586  sugar transmembrane transporter activity
# 9   P23586  sugar transmembrane transporter activity
# 10  P23586  sugar transmembrane transporter activity
# 11  P23586  sugar transmembrane transporter activity
# 12  Q0WWW9  sugar transmembrane transporter activity
# 13  Q0WWW9  sugar transmembrane transporter activity
# 14  Q0WWW9  sugar transmembrane transporter activity
# 15  Q39228  sugar transmembrane transporter activity
# 16  Q39228  sugar transmembrane transporter activity
# 17  Q39228  sugar transmembrane transporter activity
# 18  Q39228  sugar transmembrane transporter activity
# 19  Q6AWX0  sugar transmembrane transporter activity
# 20  Q6AWX0  sugar transmembrane transporter activity
# 21  Q6AWX0  sugar transmembrane transporter activity
# 22  Q6NQN5  sugar transmembrane transporter activity
# 23  Q84WN3  sugar transmembrane transporter activity
# 24  Q8GX78  sugar transmembrane transporter activity
# 25  Q8GX78  sugar transmembrane transporter activity
# 26  Q8GX78  sugar transmembrane transporter activity
# 27  Q8L9J7  sugar transmembrane transporter activity
# 28  Q8LFH5  sugar transmembrane transporter activity
# 29  Q8VZ80  sugar transmembrane transporter activity
# 30  Q8VZ80  sugar transmembrane transporter activity
# 31  Q8VZ80  sugar transmembrane transporter activity
# 32  Q8VZ80  sugar transmembrane transporter activity
# 33  Q944M5  sugar transmembrane transporter activity
# 34  Q94AZ2  sugar transmembrane transporter activity
# 35  Q94AZ2  sugar transmembrane transporter activity
# 36  Q94AZ2  sugar transmembrane transporter activity
# 37  Q94AZ2  sugar transmembrane transporter activity
# 38  Q94KE0  sugar transmembrane transporter activity
# 39  Q94KE0  sugar transmembrane transporter activity
# 40  Q94KE0  sugar transmembrane transporter activity
# 41  Q94KE0  sugar transmembrane transporter activity
# 42  Q9C9M9  sugar transmembrane transporter activity
# 43  Q9FDZ5  sugar transmembrane transporter activity
# 44  Q9FG00  sugar transmembrane transporter activity
# 45  Q9FG00  sugar transmembrane transporter activity
# 46  Q9FGQ2  sugar transmembrane transporter activity
# 47  Q9FM10  sugar transmembrane transporter activity
# 48  Q9FY94  sugar transmembrane transporter activity
# 49  Q9LH79  sugar transmembrane transporter activity
# 50  Q9LNV3  sugar transmembrane transporter activity
# 51  Q9LNV3  sugar transmembrane transporter activity
# 52  Q9LNV3  sugar transmembrane transporter activity
# 53  Q9LNV3  sugar transmembrane transporter activity
# 54  Q9LT15  sugar transmembrane transporter activity
# 55  Q9LT15  sugar transmembrane transporter activity
# 56  Q9LT15  sugar transmembrane transporter activity
# 57  Q9LT15  sugar transmembrane transporter activity
# 58  Q9LUE3  sugar transmembrane transporter activity
# 59  Q9SFG0  sugar transmembrane transporter activity
# 60  Q9SFG0  sugar transmembrane transporter activity
# 61  Q9SFG0  sugar transmembrane transporter activity
# 62  Q9SFG0  sugar transmembrane transporter activity
# 63  Q9SMM5  sugar transmembrane transporter activity
# 64  Q9ZV02  sugar transmembrane transporter activity
#
#                                         protein_names  \
# 0   Sugar transporter ERD6 (Early-responsive to de...
# 1   Sugar transporter ERD6 (Early-responsive to de...
# 2   Sugar transporter ERD6 (Early-responsive to de...
# 3   Sugar transporter ERD6 (Early-responsive to de...
# 4    Sugar transport protein 7 (Hexose transporter 7)
# 5    Sugar transport protein 7 (Hexose transporter 7)
# 6    Sugar transport protein 7 (Hexose transporter 7)
# 7    Sugar transport protein 7 (Hexose transporter 7)
# 8   Sugar transport protein 1 (Glucose transporter...
# 9   Sugar transport protein 1 (Glucose transporter...
# 10  Sugar transport protein 1 (Glucose transporter...
# 11  Sugar transport protein 1 (Glucose transporter...
# 12    D-xylose-proton symporter-like 3, chloroplastic
# 13    D-xylose-proton symporter-like 3, chloroplastic
# 14    D-xylose-proton symporter-like 3, chloroplastic
# 15   Sugar transport protein 4 (Hexose transporter 4)
# 16   Sugar transport protein 4 (Hexose transporter 4)
# 17   Sugar transport protein 4 (Hexose transporter 4)
# 18   Sugar transport protein 4 (Hexose transporter 4)
# 19                   D-xylose-proton symporter-like 2
# 20                   D-xylose-proton symporter-like 2
# 21                   D-xylose-proton symporter-like 2
# 22  Bidirectional sugar transporter SWEET3 (AtSWEE...
# 23  Bidirectional sugar transporter SWEET17 (AtSWE...
# 24  Ascorbate transporter, chloroplastic (Phosphat...
# 25  Ascorbate transporter, chloroplastic (Phosphat...
# 26  Ascorbate transporter, chloroplastic (Phosphat...
# 27  Bidirectional sugar transporter SWEET1 (AtSWEE...
# 28  Bidirectional sugar transporter SWEET8 (AtSWEE...
# 29  Polyol transporter 5 (Protein POLYOL TRANSPORT...
# 30  Polyol transporter 5 (Protein POLYOL TRANSPORT...
# 31  Polyol transporter 5 (Protein POLYOL TRANSPORT...
# 32  Polyol transporter 5 (Protein POLYOL TRANSPORT...
# 33  Bidirectional sugar transporter SWEET4 (AtSWEE...
# 34  Sugar transport protein 13 (Hexose transporter...
# 35  Sugar transport protein 13 (Hexose transporter...
# 36  Sugar transport protein 13 (Hexose transporter...
# 37  Sugar transport protein 13 (Hexose transporter...
# 38  Sugar transporter ESL1 (Protein EARLY-RESPONSI...
# 39  Sugar transporter ESL1 (Protein EARLY-RESPONSI...
# 40  Sugar transporter ESL1 (Protein EARLY-RESPONSI...
# 41  Sugar transporter ESL1 (Protein EARLY-RESPONSI...
# 42  Bidirectional sugar transporter SWEET6 (AtSWEE...
# 43  UDP-rhamnose/UDP-galactose transporter 6 (UDP-...
# 44  Sucrose transport protein SUC9 (AtSUC9) (Sucro...
# 45  Sucrose transport protein SUC9 (AtSUC9) (Sucro...
# 46  Bidirectional sugar transporter SWEET13 (AtSWE...
# 47  Bidirectional sugar transporter SWEET5 (AtSWEE...
# 48  Bidirectional sugar transporter SWEET15 (AtSWE...
# 49  Bidirectional sugar transporter SWEET2 (AtSWEE...
# 50   Sugar transport protein 2 (Hexose transporter 2)
# 51   Sugar transport protein 2 (Hexose transporter 2)
# 52   Sugar transport protein 2 (Hexose transporter 2)
# 53   Sugar transport protein 2 (Hexose transporter 2)
# 54  Sugar transport protein 10 (AtSTP10) (D-glucos...
# 55  Sugar transport protein 10 (AtSTP10) (D-glucos...
# 56  Sugar transport protein 10 (AtSTP10) (D-glucos...
# 57  Sugar transport protein 10 (AtSTP10) (D-glucos...
# 58  Bidirectional sugar transporter SWEET10 (AtSWE...
# 59   Sugar transport protein 6 (Hexose transporter 6)
# 60   Sugar transport protein 6 (Hexose transporter 6)
# 61   Sugar transport protein 6 (Hexose transporter 6)
# 62   Sugar transport protein 6 (Hexose transporter 6)
# 63  Bidirectional sugar transporter SWEET11 (AtSWE...
# 64  Bidirectional sugar transporter SWEET9 (AtSWEE...
#
#                                                Family  \
# 0                          Sugar/inositol transporter
# 1   Major Facilitator Superfamily Trehalose Transp...
# 2           Major facilitator, sugar transporter-like
# 3                   Sugar transporter ERD6/Tret1-like
# 4   Sugar transport protein STP/Polyol transporter...
# 5                          Sugar/inositol transporter
# 6         Sugar transport protein STP/MST-like, plant
# 7           Major facilitator, sugar transporter-like
# 8         Sugar transport protein STP/MST-like, plant
# 9           Major facilitator, sugar transporter-like
# 10  Sugar transport protein STP/Polyol transporter...
# 11                         Sugar/inositol transporter
# 12    Major Facilitator Superfamily Sugar Transporter
# 13                         Sugar/inositol transporter
# 14          Major facilitator, sugar transporter-like
# 15                         Sugar/inositol transporter
# 16  Sugar transport protein STP/Polyol transporter...
# 17          Major facilitator, sugar transporter-like
# 18        Sugar transport protein STP/MST-like, plant
# 19          Major facilitator, sugar transporter-like
# 20    Major Facilitator Superfamily Sugar Transporter
# 21                         Sugar/inositol transporter
# 22                            Sugar transporter SWEET
# 23                            Sugar transporter SWEET
# 24             Solute carrier family 17 member 9-like
# 25  Major Facilitator Superfamily Sodium/Anion Cot...
# 26                      Major facilitator superfamily
# 27                            Sugar transporter SWEET
# 28                            Sugar transporter SWEET
# 29          Major facilitator, sugar transporter-like
# 30                             Polyol transporter 1-6
# 31  Sugar transport protein STP/Polyol transporter...
# 32                         Sugar/inositol transporter
# 33                            Sugar transporter SWEET
# 34        Sugar transport protein STP/MST-like, plant
# 35                         Sugar/inositol transporter
# 36  Sugar transport protein STP/Polyol transporter...
# 37          Major facilitator, sugar transporter-like
# 38                         Sugar/inositol transporter
# 39                  Sugar transporter ERD6/Tret1-like
# 40          Major facilitator, sugar transporter-like
# 41  Major Facilitator Superfamily Trehalose Transp...
# 42                            Sugar transporter SWEET
# 43            Triose Phosphate/Phosphate Translocator
# 44                        Sucrose/H+ symporter, plant
# 45                      Major facilitator superfamily
# 46                            Sugar transporter SWEET
# 47                            Sugar transporter SWEET
# 48                            Sugar transporter SWEET
# 49                            Sugar transporter SWEET
# 50        Sugar transport protein STP/MST-like, plant
# 51  Sugar transport protein STP/Polyol transporter...
# 52                         Sugar/inositol transporter
# 53          Major facilitator, sugar transporter-like
# 54  Sugar transport protein STP/Polyol transporter...
# 55        Sugar transport protein STP/MST-like, plant
# 56          Major facilitator, sugar transporter-like
# 57                         Sugar/inositol transporter
# 58                            Sugar transporter SWEET
# 59                         Sugar/inositol transporter
# 60          Major facilitator, sugar transporter-like
# 61        Sugar transport protein STP/MST-like, plant
# 62  Sugar transport protein STP/Polyol transporter...
# 63                            Sugar transporter SWEET
# 64                            Sugar transporter SWEET
#
#          Homologous_superfamily
# 0   MFS transporter superfamily
# 1   MFS transporter superfamily
# 2   MFS transporter superfamily
# 3   MFS transporter superfamily
# 4   MFS transporter superfamily
# 5   MFS transporter superfamily
# 6   MFS transporter superfamily
# 7   MFS transporter superfamily
# 8   MFS transporter superfamily
# 9   MFS transporter superfamily
# 10  MFS transporter superfamily
# 11  MFS transporter superfamily
# 12  MFS transporter superfamily
# 13  MFS transporter superfamily
# 14  MFS transporter superfamily
# 15  MFS transporter superfamily
# 16  MFS transporter superfamily
# 17  MFS transporter superfamily
# 18  MFS transporter superfamily
# 19  MFS transporter superfamily
# 20  MFS transporter superfamily
# 21  MFS transporter superfamily
# 22                          NaN
# 23                          NaN
# 24  MFS transporter superfamily
# 25  MFS transporter superfamily
# 26  MFS transporter superfamily
# 27                          NaN
# 28                          NaN
# 29  MFS transporter superfamily
# 30  MFS transporter superfamily
# 31  MFS transporter superfamily
# 32  MFS transporter superfamily
# 33  MFS transporter superfamily
# 34  MFS transporter superfamily
# 35  MFS transporter superfamily
# 36  MFS transporter superfamily
# 37  MFS transporter superfamily
# 38  MFS transporter superfamily
# 39  MFS transporter superfamily
# 40  MFS transporter superfamily
# 41  MFS transporter superfamily
# 42                          NaN
# 43                          NaN
# 44  MFS transporter superfamily
# 45  MFS transporter superfamily
# 46                          NaN
# 47                          NaN
# 48                          NaN
# 49                          NaN
# 50  MFS transporter superfamily
# 51  MFS transporter superfamily
# 52  MFS transporter superfamily
# 53  MFS transporter superfamily
# 54  MFS transporter superfamily
# 55  MFS transporter superfamily
# 56  MFS transporter superfamily
# 57  MFS transporter superfamily
# 58                          NaN
# 59  MFS transporter superfamily
# 60  MFS transporter superfamily
# 61  MFS transporter superfamily
# 62  MFS transporter superfamily
# 63                          NaN
# 64                          NaN

# %%
# Some proteins have multiple rows!
get_interpro_table(
    *dataset_organism,
    go_terms=["amino acid transmembrane transporter activity"],
    interpro_types=["Family", "Homologous_superfamily", "Domain"]
)
# Out:
#    Uniprot                               go_term_ancestor  \
# 0   F4HW02  amino acid transmembrane transporter activity
# 1   F4IUW3  amino acid transmembrane transporter activity
# 2   O64759  amino acid transmembrane transporter activity
# 3   O81845  amino acid transmembrane transporter activity
# 4   O81845  amino acid transmembrane transporter activity
# 5   P57758  amino acid transmembrane transporter activity
# 6   P92961  amino acid transmembrane transporter activity
# 7   Q38967  amino acid transmembrane transporter activity
# 8   Q42400  amino acid transmembrane transporter activity
# 9   Q84MA5  amino acid transmembrane transporter activity
# 10  Q84UC7  amino acid transmembrane transporter activity
# 11  Q8GUM3  amino acid transmembrane transporter activity
# 12  Q8L4X4  amino acid transmembrane transporter activity
# 13  Q8W4K3  amino acid transmembrane transporter activity
# 14  Q93XM7  amino acid transmembrane transporter activity
# 15  Q96247  amino acid transmembrane transporter activity
# 16  Q9ASS7  amino acid transmembrane transporter activity
# 17  Q9C8E7  amino acid transmembrane transporter activity
# 18  Q9C8E7  amino acid transmembrane transporter activity
# 19  Q9C8E7  amino acid transmembrane transporter activity
# 20  Q9C8E7  amino acid transmembrane transporter activity
# 21  Q9C8E7  amino acid transmembrane transporter activity
# 22  Q9C8E7  amino acid transmembrane transporter activity
# 23  Q9C8E7  amino acid transmembrane transporter activity
# 24  Q9C8E7  amino acid transmembrane transporter activity
# 25  Q9CA93  amino acid transmembrane transporter activity
# 26  Q9CA93  amino acid transmembrane transporter activity
# 27  Q9FKS8  amino acid transmembrane transporter activity
# 28  Q9FKY3  amino acid transmembrane transporter activity
# 29  Q9FMF7  amino acid transmembrane transporter activity
# 30  Q9FMF7  amino acid transmembrane transporter activity
# 31  Q9LPF1  amino acid transmembrane transporter activity
# 32  Q9SF09  amino acid transmembrane transporter activity
# 33  Q9SVG0  amino acid transmembrane transporter activity
# 34  Q9SX98  amino acid transmembrane transporter activity
# 35  Q9ZV24  amino acid transmembrane transporter activity
#
#                                         protein_names  \
# 0   GABA transporter 1 (AtGAT1) (Bidirectional ami...
# 1              Amino acid transporter AVT1C (AtAvt1C)
# 2                   Cationic amino acid transporter 5
# 3        Mitochondrial uncoupling protein 1 (AtPUMP1)
# 4        Mitochondrial uncoupling protein 1 (AtPUMP1)
# 5                                  Cystinosin homolog
# 6                     Proline transporter 1 (AtPROT1)
# 7   Amino acid permease 2 (Amino acid transporter ...
# 8   Amino acid permease 1 (Amino acid transporter ...
# 9   Cationic amino acid transporter 1 (Amino acid ...
# 10  Mitochondrial arginine transporter BAC1 (Mitoc...
# 11  Amino acid permease 5 (Amino acid transporter ...
# 12                        Probable GABA transporter 2
# 13        Cationic amino acid transporter 4, vacuolar
# 14  Mitochondrial carnitine/acylcarnitine carrier-...
# 15  Auxin transporter protein 1 (Auxin influx carr...
# 16        Cationic amino acid transporter 2, vacuolar
# 17  Glutamate receptor 3.3 (AtGLR3.3) (Glutamate r...
# 18  Glutamate receptor 3.3 (AtGLR3.3) (Glutamate r...
# 19  Glutamate receptor 3.3 (AtGLR3.3) (Glutamate r...
# 20  Glutamate receptor 3.3 (AtGLR3.3) (Glutamate r...
# 21  Glutamate receptor 3.3 (AtGLR3.3) (Glutamate r...
# 22  Glutamate receptor 3.3 (AtGLR3.3) (Glutamate r...
# 23  Glutamate receptor 3.3 (AtGLR3.3) (Glutamate r...
# 24  Glutamate receptor 3.3 (AtGLR3.3) (Glutamate r...
# 25  Mitochondrial arginine transporter BAC2 (Mitoc...
# 26  Mitochondrial arginine transporter BAC2 (Mitoc...
# 27                     Lysine histidine transporter 1
# 28  Amino acid transporter AVT3A (AtAvt3A) (Aromat...
# 29  Dicarboxylate transporter 2.1, chloroplastic (...
# 30  Dicarboxylate transporter 2.1, chloroplastic (...
# 31                     WAT1-related protein At1g44800
# 32  Amino acid transporter ANT1 (Aromatic and neut...
# 33  Amino acid transporter AVT3C (AtAvt3C) (Aromat...
# 34  Lysine histidine transporter-like 8 (Amino aci...
# 35  Outer envelope pore protein 16-1, chloroplasti...
#
#                                   Family  \
# 0                                    NaN
# 1                                    NaN
# 2     Amino acid/polyamine transporter I
# 3          Mitochondrial carrier protein
# 4   Mitochondrial Metabolite Transporter
# 5          Lysosomal cystine transporter
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9     Amino acid/polyamine transporter I
# 10                 Mitochondrial Carrier
# 11                                   NaN
# 12                                   NaN
# 13    Amino acid/polyamine transporter I
# 14                 Mitochondrial Carrier
# 15                                   NaN
# 16    Amino acid/polyamine transporter I
# 17         Ionotropic glutamate receptor
# 18         Ionotropic glutamate receptor
# 19         Ionotropic glutamate receptor
# 20         Ionotropic glutamate receptor
# 21  Ionotropic glutamate receptor, plant
# 22  Ionotropic glutamate receptor, plant
# 23  Ionotropic glutamate receptor, plant
# 24  Ionotropic glutamate receptor, plant
# 25         Mitochondrial carrier protein
# 26                 Mitochondrial Carrier
# 27                                   NaN
# 28                                   NaN
# 29          Citrate carrier CitT-related
# 30              Solute carrier family 13
# 31                  WAT1-related protein
# 32                                   NaN
# 33                                   NaN
# 34                                   NaN
# 35                            Tim23-like
#
#                       Homologous_superfamily  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3   Mitochondrial carrier domain superfamily
# 4   Mitochondrial carrier domain superfamily
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10  Mitochondrial carrier domain superfamily
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14  Mitochondrial carrier domain superfamily
# 15                                       NaN
# 16                                       NaN
# 17        Periplasmic binding protein-like I
# 18        Periplasmic binding protein-like I
# 19        Periplasmic binding protein-like I
# 20        Periplasmic binding protein-like I
# 21        Periplasmic binding protein-like I
# 22        Periplasmic binding protein-like I
# 23        Periplasmic binding protein-like I
# 24        Periplasmic binding protein-like I
# 25  Mitochondrial carrier domain superfamily
# 26  Mitochondrial carrier domain superfamily
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# 30                                       NaN
# 31                                       NaN
# 32                                       NaN
# 33                                       NaN
# 34                                       NaN
# 35                                       NaN
#
#                                                Domain
# 0        Amino acid transporter, transmembrane domain
# 1        Amino acid transporter, transmembrane domain
# 2         Cationic amino acid transporter, C-terminal
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6        Amino acid transporter, transmembrane domain
# 7        Amino acid transporter, transmembrane domain
# 8        Amino acid transporter, transmembrane domain
# 9         Cationic amino acid transporter, C-terminal
# 10                                                NaN
# 11       Amino acid transporter, transmembrane domain
# 12       Amino acid transporter, transmembrane domain
# 13        Cationic amino acid transporter, C-terminal
# 14                                                NaN
# 15       Amino acid transporter, transmembrane domain
# 16        Cationic amino acid transporter, C-terminal
# 17  Solute-binding protein family 3/N-terminal dom...
# 18          Ionotropic glutamate receptor, C-terminal
# 19  Plant glutamate receptor, periplasmic ligand-b...
# 20                    Receptor, ligand binding region
# 21  Solute-binding protein family 3/N-terminal dom...
# 22          Ionotropic glutamate receptor, C-terminal
# 23  Plant glutamate receptor, periplasmic ligand-b...
# 24                    Receptor, ligand binding region
# 25                                                NaN
# 26                                                NaN
# 27       Amino acid transporter, transmembrane domain
# 28       Amino acid transporter, transmembrane domain
# 29                                                NaN
# 30                                                NaN
# 31                                        EamA domain
# 32       Amino acid transporter, transmembrane domain
# 33       Amino acid transporter, transmembrane domain
# 34       Amino acid transporter, transmembrane domain
# 35                                                NaN

# %% [markdown]
# Issue: GO:0004970 is connected directly to GO:0015171, but that does not make sense.

# %% [markdown]
# ## Feature generation

# %%
from subpred.features import get_features

features_list, series_labels = get_features(dataset_full=dataset_organism)
# Out:
# 2025-06-06 18:02:36.199309: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-06 18:02:36.205042: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749225756.210596  752972 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749225756.212480  752972 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-06 18:02:36.219441: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# For each Feature: Outlier detection, numpy conversion

# %%
from subpred.features import get_ml_datasets

ml_datasets = list(
    get_ml_datasets(features_list=features_list, series_labels=series_labels)
)
ml_datasets
# Out:
# [Name: DUMMY, Features: 1024, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: AAC, Features: 20, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PAAC, Features: 400, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: AA_KMER3, Features: 8000, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: 3Di_COMP, Features: 20, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: 3Di_KMER2, Features: 400, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: 3Di_KMER3, Features: 8000, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: COMB_KMER1, Features: 40, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: COMB_KMER2, Features: 800, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: COMB_KMER3, Features: 16000, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PROTT5_AA, Features: 1024, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PROSTT5_AA, Features: 1024, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PROSTT5_3DI, Features: 1024, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PSSM_50_1, Features: 400, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PSSM_50_3, Features: 400, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PSSM_90_1, Features: 400, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PSSM_90_3, Features: 400, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PSSM_META, Features: 1600, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: META, Features: 2020, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: META_STD, Features: 2020, Samples: 54, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity'])]

# %% [markdown]
# ## Outliers

# %%
from subpred.evaluation import outlier_check
print(len(ml_datasets))
df_outliers = outlier_check(dataset_full=dataset_organism, ml_datasets=ml_datasets, threshold=0.5)
# df_outliers[df_outliers.outlier_count>df_outliers.outlier_count.quantile(0.95)]
df_outliers
# Out:
# 20
#          outlier_count                                      protein_names  \
# Uniprot
# Q9ZV24              12  Outer envelope pore protein 16-1, chloroplasti...
# Q9C8E7              10  Glutamate receptor 3.3 (AtGLR3.3) (Glutamate r...
# P57758              10                                 Cystinosin homolog
#
#                                       go_term_ancestor
# Uniprot
# Q9ZV24   amino acid transmembrane transporter activity
# Q9C8E7   amino acid transmembrane transporter activity
# P57758   amino acid transmembrane transporter activity

# %% [markdown]
# #### Automatic outlier removal

# %%
# they were found with the outliers_check function below
potential_outliers = df_outliers.index.tolist()
dataset_organism = (
    dataset_organism[0][~(dataset_organism[0].index.isin(potential_outliers))],
    dataset_organism[1][~(dataset_organism[1].index.isin(potential_outliers))],
)
dataset_organism[1].go_term_ancestor.value_counts()
# Out:
# go_term_ancestor
# sugar transmembrane transporter activity         28
# amino acid transmembrane transporter activity    23
# Name: count, dtype: int64

# %%
features_list, series_labels = get_features(dataset_full=dataset_organism)
ml_datasets = list(
    get_ml_datasets(features_list=features_list, series_labels=series_labels)
)
ml_datasets
# Out:
# [Name: DUMMY, Features: 1024, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: AAC, Features: 20, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PAAC, Features: 400, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: AA_KMER3, Features: 8000, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: 3Di_COMP, Features: 20, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: 3Di_KMER2, Features: 400, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: 3Di_KMER3, Features: 8000, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: COMB_KMER1, Features: 40, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: COMB_KMER2, Features: 800, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: COMB_KMER3, Features: 16000, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PROTT5_AA, Features: 1024, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PROSTT5_AA, Features: 1024, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PROSTT5_3DI, Features: 1024, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PSSM_50_1, Features: 400, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PSSM_50_3, Features: 400, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PSSM_90_1, Features: 400, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PSSM_90_3, Features: 400, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: PSSM_META, Features: 1600, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: META, Features: 2020, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity']),
#  Name: META_STD, Features: 2020, Samples: 51, Classes: [0 1], Labels: ['amino acid transmembrane transporter activity'
#   'sugar transmembrane transporter activity'])]

# %% [markdown]
# ### Saving data for DNNs

# %%
# saving as pickle, to load in different notebook with different env,
# as tensorflow on GPU has problems with current CUDA version (too new)
import pickle

with open(f"{FEATURES_FOLDER}{TEST_NAME}_ml_data.pickle", "wb") as handle:
    pickle.dump(ml_datasets, handle)

# %% [markdown]
# ## Model evaluation SVM

# %%
from subpred.evaluation import (
    get_svm_results,
    plot_results_long,
    summarize_results_long,
)
from sklearn.metrics import f1_score, make_scorer

scoring_outer = {
    "Balanced Accuracy": "balanced_accuracy",
    "F1 Macro": "f1_macro",
    "F1 Amino Acid": make_scorer(
        f1_score, pos_label=0
    ),  # labels are encoded in lex. order
    "F1 Sugar": make_scorer(f1_score, pos_label=1),
}

df_results_long = get_svm_results(
    ml_datasets=ml_datasets,
    recalculate=RECALCULATE_RESULTS,
    output_folder=RESULTS_FOLDER,
    test_name=TEST_NAME,
    inner_cv=5,
    outer_cv=5,
    repeats=5,
    n_jobs_inner=1,
    n_jobs_outer=-1,
    scoring_inner="balanced_accuracy",
    scoring_outer=scoring_outer,
)
# df_results_long

# %%
df_summary = summarize_results_long(df_results_long=df_results_long)
df_summary
# Out:
#                                    Mean    Median      Sdev
# Feature     Metric
# 3Di_COMP    Balanced Accuracy  0.933667  1.000000  0.097909
#             F1 Amino Acid      0.915062  1.000000  0.139848
#             F1 Macro           0.934497  1.000000  0.100733
#             F1 Sugar           0.953931  1.000000  0.064793
# 3Di_KMER2   Balanced Accuracy  0.967000  1.000000  0.045674
#             F1 Amino Acid      0.961154  1.000000  0.053699
#             F1 Macro           0.964369  1.000000  0.048614
#             F1 Sugar           0.967584  1.000000  0.044486
# 3Di_KMER3   Balanced Accuracy  0.899333  0.900000  0.077874
#             F1 Amino Acid      0.890820  0.888889  0.088377
#             F1 Macro           0.901271  0.898990  0.077226
#             F1 Sugar           0.911723  0.923077  0.073348
# AAC         Balanced Accuracy  0.766000  0.750000  0.115893
#             F1 Amino Acid      0.731030  0.727273  0.138534
#             F1 Macro           0.750468  0.696970  0.125098
#             F1 Sugar           0.769906  0.800000  0.146652
# AA_KMER3    Balanced Accuracy  0.769667  0.750000  0.133092
#             F1 Amino Acid      0.773661  0.769231  0.126050
#             F1 Macro           0.750249  0.727273  0.144570
#             F1 Sugar           0.726837  0.727273  0.170822
# COMB_KMER1  Balanced Accuracy  0.951000  1.000000  0.079797
#             F1 Amino Acid      0.944993  1.000000  0.091469
#             F1 Macro           0.947838  1.000000  0.087104
#             F1 Sugar           0.950684  1.000000  0.085967
# COMB_KMER2  Balanced Accuracy  0.937667  1.000000  0.083233
#             F1 Amino Acid      0.933720  1.000000  0.086155
#             F1 Macro           0.933423  1.000000  0.088376
#             F1 Sugar           0.933125  1.000000  0.091852
# COMB_KMER3  Balanced Accuracy  0.913667  0.916667  0.088483
#             F1 Amino Acid      0.906424  0.909091  0.096576
#             F1 Macro           0.911479  0.905983  0.089744
#             F1 Sugar           0.916533  0.909091  0.085663
# DUMMY       Balanced Accuracy  0.479667  0.500000  0.136084
#             F1 Amino Acid      0.354008  0.363636  0.231889
#             F1 Macro           0.443847  0.450549  0.140759
#             F1 Sugar           0.533685  0.545455  0.156403
# META        Balanced Accuracy  0.810333  0.833333  0.153683
#             F1 Amino Acid      0.783192  0.800000  0.180659
#             F1 Macro           0.797899  0.800000  0.161021
#             F1 Sugar           0.812606  0.833333  0.152757
# META_STD    Balanced Accuracy  0.869000  0.916667  0.135326
#             F1 Amino Acid      0.843515  0.888889  0.176137
#             F1 Macro           0.859698  0.898990  0.145663
#             F1 Sugar           0.875881  0.909091  0.126307
# PAAC        Balanced Accuracy  0.881333  0.900000  0.104701
#             F1 Amino Acid      0.864291  0.909091  0.134260
#             F1 Macro           0.871463  0.898990  0.111797
#             F1 Sugar           0.878634  0.888889  0.095268
# PROSTT5_3DI Balanced Accuracy  0.949333  1.000000  0.054852
#             F1 Amino Acid      0.942395  1.000000  0.062370
#             F1 Macro           0.950654  1.000000  0.052569
#             F1 Sugar           0.958912  1.000000  0.044237
# PROSTT5_AA  Balanced Accuracy  0.948333  1.000000  0.059755
#             F1 Amino Acid      0.941804  1.000000  0.068748
#             F1 Macro           0.947879  1.000000  0.059464
#             F1 Sugar           0.953955  1.000000  0.051824
# PROTT5_AA   Balanced Accuracy  0.921333  0.900000  0.072652
#             F1 Amino Acid      0.910072  0.909091  0.092360
#             F1 Macro           0.923929  0.898990  0.069034
#             F1 Sugar           0.937787  0.923077  0.050825
# PSSM_50_1   Balanced Accuracy  0.648667  0.666667  0.189613
#             F1 Amino Acid      0.573094  0.666667  0.269418
#             F1 Macro           0.626575  0.633333  0.200400
#             F1 Sugar           0.680056  0.666667  0.158289
# PSSM_50_3   Balanced Accuracy  0.795000  0.816667  0.146645
#             F1 Amino Acid      0.750981  0.800000  0.193250
#             F1 Macro           0.785879  0.816667  0.153557
#             F1 Sugar           0.820777  0.833333  0.122047
# PSSM_90_1   Balanced Accuracy  0.815667  0.833333  0.138450
#             F1 Amino Acid      0.790993  0.800000  0.169096
#             F1 Macro           0.805843  0.800000  0.150409
#             F1 Sugar           0.820694  0.833333  0.145272
# PSSM_90_3   Balanced Accuracy  0.815667  0.833333  0.138450
#             F1 Amino Acid      0.790993  0.800000  0.169096
#             F1 Macro           0.805843  0.800000  0.150409
#             F1 Sugar           0.820694  0.833333  0.145272
# PSSM_META   Balanced Accuracy  0.841667  0.900000  0.138235
#             F1 Amino Acid      0.812009  0.888889  0.173240
#             F1 Macro           0.829429  0.898990  0.147564
#             F1 Sugar           0.846850  0.909091  0.133179

# %%
plot_results_long(
    df_results_long=df_results_long,
    output_folder_path=RESULTS_FOLDER,
    test_name=TEST_NAME,
    metrics_include=["F1 Amino Acid", "F1 Sugar"],
    figsize=(12, 6),
)

# %%
plot_results_long(
    df_results_long=df_results_long,
    output_folder_path=RESULTS_FOLDER,
    test_name=TEST_NAME,
    metrics_include=["F1 Macro", "Balanced Accuracy"],
)

# %% [markdown]
# ### Plots for paper

# %%
df_results_long_plots = df_results_long.copy()
df_results_long_plots["Feature"] =  df_results_long_plots["Feature"].replace("PSSM_META", "MULTI_PSSM").replace("PROSTT5_3DI","PROSTT5_3Di")

# %%
df_results_long_plots.Feature.unique()
# Out:
# array(['DUMMY', 'AAC', 'PAAC', 'AA_KMER3', '3Di_COMP', '3Di_KMER2',
#        '3Di_KMER3', 'COMB_KMER1', 'COMB_KMER2', 'COMB_KMER3', 'PROTT5_AA',
#        'PROSTT5_AA', 'PROSTT5_3Di', 'PSSM_50_1', 'PSSM_50_3', 'PSSM_90_1',
#        'PSSM_90_3', 'MULTI_PSSM', 'META', 'META_STD'], dtype=object)

# %%
feature_names = [
    "DUMMY",
    "AAC",
    "PAAC",
    "AA_KMER3",
    # "PSSM_META",
    "MULTI_PSSM",
    "META",
    "META_STD",
    # "COMB_KMER1",
    # "COMB_KMER2",
    # "COMB_KMER3",
    "PROTT5_AA",
    "PROSTT5_AA",
    # "PROSTT5_3DI",
    "PROSTT5_3Di",
    "3Di_COMP",
    "3Di_KMER2",
    "3Di_KMER3",
    # "PSSM_50_1",
    # "PSSM_50_3",
    # "PSSM_90_1",
    # "PSSM_90_3",
]
df_results_long_plots_filtered = df_results_long_plots[df_results_long_plots.Feature.isin(feature_names)].copy()

# %%
df_results_long_plots_filtered.Feature = df_results_long_plots_filtered.Feature.str.replace("_","-")
feature_names = [feature_name.replace("_","-") for feature_name in feature_names]

# %%
plot_results_long(
    df_results_long=df_results_long_plots_filtered,
    output_folder_path=RESULTS_FOLDER,
    test_name=TEST_NAME+"_filtered",
    metrics_include=["F1 Amino Acid", "F1 Sugar"],
    figsize=(12, 6),
    y_max=1.05,
    plot_order=feature_names,
    plot_type="box"
)

# %% [markdown]
# ### Tables

# %%
df_table = df_results_long.copy()
df_table.Feature = df_table.Feature.str.replace("_", "-")
df_table = df_table[~df_table.Feature.str.match(r'^PSSM-\d+')]
feature_order = [
    "DUMMY",
    "AAC",
    "PAAC",
    "AA-KMER3",
    "PSSM-META",
    "META",
    "META-STD",
    "COMB-KMER1",
    "COMB-KMER2",
    "COMB-KMER3",
    "PROTT5-AA",
    "PROSTT5-AA",
    "PROSTT5-3DI",
    # "PSSM-50-1",
    # "PSSM-50-3",
    # "PSSM-90-1",
    # "PSSM-90-3",
    "3Di-COMP",
    "3Di-KMER2",
    "3Di-KMER3",
]

df_table_mean = df_table.groupby(["Feature", "Metric"]).mean().reset_index().pivot(
    index="Feature", columns="Metric", values="Value"
)
df_table_std = df_table.groupby(["Feature", "Metric"]).std().reset_index().pivot(
    index="Feature", columns="Metric", values="Value"
)

df_table_paper = df_table_mean.map(lambda x: f"{x:.3f}").astype(str) + "±" + df_table_std.map(lambda x: f"{x:.3f}").astype(str)
df_table_paper = df_table_paper.loc[feature_order]
df_table_paper
# Out:
# Metric      Balanced Accuracy F1 Amino Acid     F1 Macro     F1 Sugar
# Feature
# DUMMY             0.480±0.136   0.354±0.232  0.444±0.141  0.534±0.156
# AAC               0.766±0.116   0.731±0.139  0.750±0.125  0.770±0.147
# PAAC              0.881±0.105   0.864±0.134  0.871±0.112  0.879±0.095
# AA-KMER3          0.770±0.133   0.774±0.126  0.750±0.145  0.727±0.171
# PSSM-META         0.842±0.138   0.812±0.173  0.829±0.148  0.847±0.133
# META              0.810±0.154   0.783±0.181  0.798±0.161  0.813±0.153
# META-STD          0.869±0.135   0.844±0.176  0.860±0.146  0.876±0.126
# COMB-KMER1        0.951±0.080   0.945±0.091  0.948±0.087  0.951±0.086
# COMB-KMER2        0.938±0.083   0.934±0.086  0.933±0.088  0.933±0.092
# COMB-KMER3        0.914±0.088   0.906±0.097  0.911±0.090  0.917±0.086
# PROTT5-AA         0.921±0.073   0.910±0.092  0.924±0.069  0.938±0.051
# PROSTT5-AA        0.948±0.060   0.942±0.069  0.948±0.059  0.954±0.052
# PROSTT5-3DI       0.949±0.055   0.942±0.062  0.951±0.053  0.959±0.044
# 3Di-COMP          0.934±0.098   0.915±0.140  0.934±0.101  0.954±0.065
# 3Di-KMER2         0.967±0.046   0.961±0.054  0.964±0.049  0.968±0.044
# 3Di-KMER3         0.899±0.078   0.891±0.088  0.901±0.077  0.912±0.073

# %%
df_table_latex = df_table_paper.copy()
df_table_latex.columns.name = None
print(
    df_table_latex.reset_index(drop=False)
    .drop("F1 Macro", axis=1)
    .to_latex(index=False)
    .replace("tabular", "tabular*")
    .replace("{llll}", "{\\textwidth}{@{\\extracolsep{\\fill}} lrrr}")
)
# Out:
# \begin{tabular*}{\textwidth}{@{\extracolsep{\fill}} lrrr}
# \toprule
# Feature & Balanced Accuracy & F1 Amino Acid & F1 Sugar \\
# \midrule
# DUMMY & 0.480±0.136 & 0.354±0.232 & 0.534±0.156 \\
# AAC & 0.766±0.116 & 0.731±0.139 & 0.770±0.147 \\
# PAAC & 0.881±0.105 & 0.864±0.134 & 0.879±0.095 \\
# AA-KMER3 & 0.770±0.133 & 0.774±0.126 & 0.727±0.171 \\
# PSSM-META & 0.842±0.138 & 0.812±0.173 & 0.847±0.133 \\
# META & 0.810±0.154 & 0.783±0.181 & 0.813±0.153 \\
# META-STD & 0.869±0.135 & 0.844±0.176 & 0.876±0.126 \\
# COMB-KMER1 & 0.951±0.080 & 0.945±0.091 & 0.951±0.086 \\
# COMB-KMER2 & 0.938±0.083 & 0.934±0.086 & 0.933±0.092 \\
# COMB-KMER3 & 0.914±0.088 & 0.906±0.097 & 0.917±0.086 \\
# PROTT5-AA & 0.921±0.073 & 0.910±0.092 & 0.938±0.051 \\
# PROSTT5-AA & 0.948±0.060 & 0.942±0.069 & 0.954±0.052 \\
# PROSTT5-3DI & 0.949±0.055 & 0.942±0.062 & 0.959±0.044 \\
# 3Di-COMP & 0.934±0.098 & 0.915±0.140 & 0.954±0.065 \\
# 3Di-KMER2 & 0.967±0.046 & 0.961±0.054 & 0.968±0.044 \\
# 3Di-KMER3 & 0.899±0.078 & 0.891±0.088 & 0.912±0.073 \\
# \bottomrule
# \end{tabular*}
